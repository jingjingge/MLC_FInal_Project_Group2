# %%
import pandas as pd
import numpy
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
tree_census = gpd.read_file("/content/drive/MyDrive/MLC project/Data processing/2015 Street Tree Census - Tree Data.geojson")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-178d0c068dc0> in <module>
# ----> 1 tree_census = gpd.read_file("/content/drive/MyDrive/MLC project/Data processing/2015 Street Tree Census - Tree Data.geojson")
#
# /usr/local/lib/python3.7/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     243
#     244             return GeoDataFrame.from_features(
# --> 245                 f_filt, crs=crs, columns=columns + ["geometry"]
#     246             )
#     247
#
# /usr/local/lib/python3.7/dist-packages/geopandas/geodataframe.py in from_features(cls, features, crs, columns)
#     608             row.update(feature["properties"])
#     609             rows.append(row)
# --> 610         return GeoDataFrame(rows, columns=columns, crs=crs)
#     611
#     612     @classmethod
#
# ...

# %%
tree_census
# Out:
#         created_at  tree_id  block_id  \
# 0       08/27/2015   180683    348711
# 1       09/03/2015   200540    315986
# 2       09/05/2015   204026    218365
# 3       09/05/2015   204337    217969
# 4       08/30/2015   189565    223043
# ...            ...      ...       ...
# 683783  08/18/2015   155433    217978
# 683784  08/29/2015   183795    348185
# 683785  08/22/2015   166161    401670
# 683786  08/29/2015   184028    504204
# 683787  09/03/2015   200607    306527
#
#                                              the_geom  tree_dbh  stump_diam  \
# 0       POINT (-73.84421521958048 40.723091773924274)         3           0
# 1        POINT (-73.81867945834878 40.79411066708779)        21           0
# 2       POINT (-73.93660770459083 40.717580740099116)         3           0
# 3       POINT (-73.93445615919741 40.713537494833226)        10           0
# 4        POINT (-73.97597938483258 40.66677775537875)        21           0
# ...

# %%
gdf = gpd.GeoDataFrame(tree_census, crs='epsg:2263')

# %%
gdf
# Out:
#         created_at  tree_id  block_id  \
# 0       08/27/2015   180683    348711
# 1       09/03/2015   200540    315986
# 2       09/05/2015   204026    218365
# 3       09/05/2015   204337    217969
# 4       08/30/2015   189565    223043
# ...            ...      ...       ...
# 683783  08/18/2015   155433    217978
# 683784  08/29/2015   183795    348185
# 683785  08/22/2015   166161    401670
# 683786  08/29/2015   184028    504204
# 683787  09/03/2015   200607    306527
#
#                                              the_geom  tree_dbh  stump_diam  \
# 0       POINT (-73.84421521958048 40.723091773924274)         3           0
# 1        POINT (-73.81867945834878 40.79411066708779)        21           0
# 2       POINT (-73.93660770459083 40.717580740099116)         3           0
# 3       POINT (-73.93445615919741 40.713537494833226)        10           0
# 4        POINT (-73.97597938483258 40.66677775537875)        21           0
# ...

# %%
# Read the data.
zipcode = gpd.GeoDataFrame.from_file('/content/drive/MyDrive/MLC project/Data processing/ZIP_CODE_040114 2/ZIP_CODE_040114.shp')
tree = gpd.GeoDataFrame.from_file("/content/drive/MyDrive/MLC project/Data processing/2015StreetTreesCensus_TREES.csv")
'''
zipcode.merge(
    zipcode.sjoin(
        gdf
    ).groupby(
        'ZIPCODE'
    ).count().geometry.rename(
        'n_points'
    ).reset_index())
'''
# Out:
# "\nzipcode.merge(\n    zipcode.sjoin(\n        gdf\n    ).groupby(\n        'ZIPCODE'\n    ).count().geometry.rename(\n        'n_points'\n    ).reset_index())\n"

# %%
tree
# Out:
#         created_at tree_id block_id  \
# 0       08/27/2015  180683   348711
# 1       09/03/2015  200540   315986
# 2       09/05/2015  204026   218365
# 3       09/05/2015  204337   217969
# 4       08/30/2015  189565   223043
# ...            ...     ...      ...
# 683783  08/18/2015  155433   217978
# 683784  08/29/2015  183795   348185
# 683785  08/22/2015  166161   401670
# 683786  08/29/2015  184028   504204
# 683787  09/03/2015  200607   306527
#
#                                              the_geom tree_dbh stump_diam  \
# 0       POINT (-73.84421521958048 40.723091773924274)        3          0
# 1        POINT (-73.81867945834878 40.79411066708779)       21          0
# 2       POINT (-73.93660770459083 40.717580740099116)        3          0
# 3       POINT (-73.93445615919741 40.713537494833226)       10          0
# 4        POINT (-73.97597938483258 40.66677775537875)       21          0
# ...                                               ...      ...        ...
# ...

# %%
# !pip uninstall rtree
# !brew install spatialindex
# !pip install rtree
# !pip install pygeos
# Out:
# Found existing installation: Rtree 1.0.1
# Uninstalling Rtree-1.0.1:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/Rtree-1.0.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/Rtree.libs/libspatialindex-91fc2909.so.6.1.1
#     /usr/local/lib/python3.7/dist-packages/rtree/*
# Proceed (y/n)? y
#   Successfully uninstalled Rtree-1.0.1
# /bin/bash: brew: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached Rtree-1.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.1 MB 14.2 MB/s
# ...

# %%
gdf_tree = gpd.GeoDataFrame(tree_census, crs='epsg:2263')
df_tree = gpd.sjoin(gdf_tree, zipcode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f82fbc09d34f> in <module>
#       3
#       4 gdf_tree = gpd.GeoDataFrame(tree_census, crs='epsg:2263')
# ----> 5 df_tree = gpd.sjoin(gdf_tree, zipcode)
#
# /usr/local/lib/python3.7/dist-packages/geopandas/tools/sjoin.py in sjoin(left_df, right_df, how, predicate, lsuffix, rsuffix, **kwargs)
#     122     _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#     123
# --> 124     indices = _geom_predicate_query(left_df, right_df, predicate)
#     125
#     126     joined = _frame_join(indices, left_df, right_df, how, lsuffix, rsuffix)
#
# /usr/local/lib/python3.7/dist-packages/geopandas/tools/sjoin.py in _geom_predicate_query(left_df, right_df, predicate)
#     214             # all other predicates are symmetric
#     215             # keep them the same
# --> 216             sindex = right_df.sindex
# ...

# %%
# Make a copy because I'm going to drop points as I
# assign them to polys, to speed up subsequent search.
pts = tree_census.copy() 

# We're going to keep a list of how many points we find.
pts_in_polys = []

# Loop over polygons with index i.
for i, poly in zipcode.iterrows():

    # Keep a list of points in this poly
    pts_in_this_poly = []

    # Now loop over all points with index j.
    for j, pt in pts.iterrows():
        if poly.geometry.contains(pt.geometry):
            # Then it's a hit! Add it to the list,
            # and drop it so we have less hunting.
            pts_in_this_poly.append(pt.geometry)
            pts = pts.drop([j])

    # We could do all sorts, like grab a property of the
    # points, but let's just append the number of them.
    pts_in_polys.append(len(pts_in_this_poly))

# Add the number of points for each poly to the dataframe.
zipcode['number of points'] = gpd.GeoSeries(pts_in_polys)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c231e80a9c3c> in <module>
#      17     # Now loop over all points with index j.
#      18     for j, pt in pts.iterrows():
# ---> 19         if poly.geometry.contains(pt.geometry):
#      20             # Then it's a hit! Add it to the list,
#      21             # and drop it so we have less hunting.
#
# /usr/local/lib/python3.7/dist-packages/shapely/geometry/base.py in contains(self, other)
#     768     def contains(self, other):
#     769         """Returns True if the geometry contains the other, else False"""
# --> 770         return bool(self.impl['contains'](self, other))
#     771
#     772     def crosses(self, other):
#
# /usr/local/lib/python3.7/dist-packages/shapely/impl.py in __getitem__(self, key)
#      54         self.map.update(values)
#      55
# ---> 56     def __getitem__(self, key):
# ...
